# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from IPython.display import clear_output
import time

s = 1000

file1 = open("logs/r2_log.txt")
text = file1.read()
file1.close()

ep_wins = []
for x in text.split("\n")[0:]:
    if x != "":
        try:
            ep_wins.append(float(x))
        except:print("error:", x)
        

ep_total = []
cr = 0
for i in ep_wins:
  cr += i
  ep_total.append(cr)


ep_s = ep_wins
x1 = [np.average(ep_s[i-s+1:i+1])for i in tqdm(range(s-1,len(ep_s)))]
x2 = [v for v in tqdm(ep_wins)]
clear_output()



plt.figure(figsize=(30,8))
plt.axhline(y=0, color = "green", linewidth=2)
plt.plot(x1, linewidth=1, color = "blue")
#plt.bar([i for i in range(len(x1))], x1)

plt.figure(figsize=(30,8))
plt.plot(ep_total)
plt.show()

# %%
s = 1000

file1 = open("logs/num_trades_per_day.txt")
text = file1.read()
file1.close()

x1 = []
for x in text.split("\n")[0:]:
    if x != "":
        try:
            x1.append(float(x))
        except:print("error:", x)
        
x1 = [np.average(x1[i-s+1:i+1])for i in tqdm(range(s,len(x1)))]

plt.figure(figsize=(30,8))

plt.plot(x1, linewidth=1, color = "blue")
#plt.bar([i for i in range(len(x1))], x1)
# Out:
# 0it [00:00, ?it/s]

# %%
file1 = open("logs/rewards_log.txt")
text = file1.read()
file1.close()

rewards = [float(x) for x in text.split("\n")[0:] if x != ""]


fig, ax = plt.subplots(1,1,figsize=(30,5))
#ax[0].plot(rewards)

s = [0]
for i in rewards:
    z = s[-1]+i
    s.append(z)
ax.plot(s)

# %%
s=1
#s2 = 30000

file1 = open("logs/loss_log.txt", "rb")
text = str(file1.read().decode())
file1.close()
print(text)


x = [float(x) for x in text.split("\n")[0:] if x != ""][3:]
weights = [m+1 for m in range(s)]
x1=[np.average(x[i-s+1:i+1], weights = None)for i in tqdm(range(s,len(x)))]
#x2=[np.average(x[max(0,i-s2+1):i+1])for i in tqdm(range(s,len(x)))]

file1 = open("logs/qv_log.txt", "rb")
text = file1.read().decode()
file1.close()
print(text)

y = [float(x) for x in text.split("\n")[0:] if x != ""]
weights = [m+1 for m in range(s)]
y1=[np.average(y[i-s+1:i+1], weights = None)for i in tqdm(range(s,len(y)))]
print(x1)

clear_output()
fig, ax = plt.subplots(2,1,figsize=(30,14))
#ax[0].set_ylim(0,1)
ax[0].plot(x1)
#ax[0].plot(x2)
#ax[1].set_ylim(0,2)
ax[1].plot(y1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<?, ?it/s]
# 0.16129510757699608
# 0.04860417974682955
# 0.11131121777510271
# 0.04383425925626651
# 0.024216864146403855
#
# 6.26537419128418
# 6.107419508356713
# 4.959766779031668
# 4.044412592669705
#
# [0.024216864146403855]

# %%
#plt.plot([100*1.02**x for x in range(30)])

# %%
file1 = open("logs/loss_log.txt", "rb")
text = str(file1.read().decode())
file1.close()
print(text)
# Out:
# 0.16129510757699608
# 0.04860417974682955
# 0.11131121777510271
# 0.04383425925626651
